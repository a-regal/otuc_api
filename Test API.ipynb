# %%
import requests

# %%
response = requests.post('http://127.0.0.1:8000/hexagons', json={'year':2018, 'month':9, 'day':7, 'hour':23, 'minute':48})

# %%
response.json()
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'id': '0',
#    'type': 'Feature',
#    'properties': {'LOCATION_SPEED': 62.892,
#     'day': 7,
#     'hex': '888e62c283fffff',
#     'hour': 23,
#     'minute': 48,
#     'month': 9,
#     'year': 2018},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-77.00503102056477, -12.02568960360114],
#       [-77.00934986028216, -12.02873640101745],
#       [-77.00884417588966, -12.03392991598545],
#       [-77.00401952508732, -12.03607652800224],
#       [-76.99970073056193, -12.03302964558803],
#       [-77.0002065416375, -12.02783623616481],
#       [-77.00503102056477, -12.02568960360114]]]},
#    'bbox': [-77.00934986028216,
#     -12.03607652800224,
#     -76.99970073056193,
#     -12.02568960360114]},
#   {'id': '1',
#    'type': 'Feature',
#    'properties': {'LOCATION_SPEED': 0.0,
#     'day': 7,
#     'hex': '888e62c331fffff',
#     'hour': 23,
#     'minute': 48,
#     'month': 9,
#     'year': 2018},
# ...
